# %% [markdown]
# # Dự đoán giá nhà
#
# ### 1. Problem definition:
# Goal : dự đoán giá nhà

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import tarfile

# Open the .gz file in binary mode.
with tarfile.open("./gdrive/My Drive/Housing_Prices_Competition/train.csv") as f:
    # Extract the contents of the .gz file to the current working directory.
    f.extractall()

# Close the .gz file.
f.close()

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("./gdrive/My Drive/Housing_Prices_Competition/train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data = pd.read_csv("./gdrive/My Drive/Housing_Prices_Competition/train.csv", index_col = "Id")

# %%
data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %% [markdown]
# ### 2. Feature selection

# %%
features = ["LotArea","YearBuilt","1stFlrSF","2ndFlrSF","FullBath","BedroomAbvGr","TotRmsAbvGrd"]

# %% [markdown]
# ### 3.Splitting dataset into X and y
# 3.1 dataset -> X,y

# %%
X = data[features]
y = data["SalePrice"]

# %%
data.shape
# Out:
# (1460, 80)

# %%
X.shape
# Out:
# (1460, 7)

# %%
y.shape
# Out:
# (1460,)

# %% [markdown]
# #### 3.2 X,y -> X_train, y_train, X_test, y_test

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X,y,train_size=0.8, test_size=0.2, random_state=0)

# %% [markdown]
# 4. Trainning Machine Learning Model

# %%
from sklearn.tree import DecisionTreeRegressor

dt_model = DecisionTreeRegressor(random_state=1)

# %%
#fit trainning data into model
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
y_preds = dt_model.predict(X_valid.head())

# %%
y_preds
# Out:
# array([335000., 140200., 119000., 207500., 112000.])

# %%
pd.DataFrame({"y": y_valid.head(), "y_preds" : y_preds})
# Out:
#           y   y_preds
# Id
# 530  200624  335000.0
# 492  133000  140200.0
# 460  110000  119000.0
# 280  192000  207500.0
# 656   88000  112000.0

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
rf_model = RandomForestRegressor(random_state=1)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
rf_val_preds = rf_model.predict(X_valid)

# %%
rf_val_preds[:5]
# Out:
# array([271690., 155039., 122024., 188915.,  91147.])

# %%
pd.DataFrame({"y": y_valid.head(), "rf_val_preds" : rf_val_preds[:5]})
# Out:
#           y  rf_val_preds
# Id
# 530  200624      271690.0
# 492  133000      155039.0
# 460  110000      122024.0
# 280  192000      188915.0
# 656   88000       91147.0

# %% [markdown]
# # Predict with a new input

# %%
X_valid.head()
# Out:
#      LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# Id
# 530    32668       1957      2515         0         3             4
# 492     9490       1941       958       620         1             3
# 460     7015       1950       979       224         1             3
# 280    10005       1977      1156       866         2             4
# 656     1680       1971       525       567         1             3
#
#      TotRmsAbvGrd
# Id
# 530             9
# 492             5
# 460             5
# 280             8
# 656             6

# %%
new_input = [[6969,2021,1000,800,4,5,8]]
rf_model.predict(new_input)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([206158.4])
